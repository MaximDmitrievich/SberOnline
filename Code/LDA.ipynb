# %%
import nltk
import re
import numpy as np
import pandas as pd
from pprint import pprint
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.test.utils import datapath
# spacy for lemmatization
import ru2
import spacy
# Plotting tools
# !pip install pyLDAvis
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# C:\Users\mdere\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Requirement already satisfied: pyLDAvis in c:\users\mdere\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: joblib>=0.8.4 in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (0.13.2)
# Requirement already satisfied: pandas>=0.17.0 in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (0.24.2)
# Requirement already satisfied: scipy>=0.18.0 in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (1.5.0)
# Requirement already satisfied: wheel>=0.23.0 in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (0.33.4)
# Requirement already satisfied: funcy in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (1.14)
# Requirement already satisfied: jinja2>=2.7.2 in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (2.10.1)
# Requirement already satisfied: pytest in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (5.0.1)
# Requirement already satisfied: future in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (0.17.1)
# Requirement already satisfied: numexpr in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (2.6.9)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\mdere\anaconda3\lib\site-packages (from pyLDAvis) (1.16.4)
# Requirement already satisfied: pytz>=2011k in c:\users\mdere\anaconda3\lib\site-packages (from pandas>=0.17.0->pyLDAvis) (2020.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\mdere\anaconda3\lib\site-packages (from pandas>=0.17.0->pyLDAvis) (2.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mdere\anaconda3\lib\site-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: py>=1.5.0 in c:\users\mdere\anaconda3\lib\site-packages (from pytest->pyLDAvis) (1.8.0)
# Requirement already satisfied: packaging in c:\users\mdere\anaconda3\lib\site-packages (from pytest->pyLDAvis) (19.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mdere\anaconda3\lib\site-packages (from pytest->pyLDAvis) (19.1.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\mdere\anaconda3\lib\site-packages (from pytest->pyLDAvis) (7.0.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\mdere\anaconda3\lib\site-packages (from pytest->pyLDAvis) (1.3.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\mdere\anaconda3\lib\site-packages (from pytest->pyLDAvis) (0.12.0)
# Requirement already satisfied: importlib-metadata>=0.12 in c:\users\mdere\anaconda3\lib\site-packages (from pytest->pyLDAvis) (0.17)
# Requirement already satisfied: wcwidth in c:\users\mdere\appdata\roaming\python\python37\site-packages (from pytest->pyLDAvis) (0.1.9)
# Requirement already satisfied: colorama in c:\users\mdere\appdata\roaming\python\python37\site-packages (from pytest->pyLDAvis) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\mdere\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.5.0->pandas>=0.17.0->pyLDAvis) (1.12.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mdere\anaconda3\lib\site-packages (from packaging->pytest->pyLDAvis) (2.4.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mdere\anaconda3\lib\site-packages (from importlib-metadata>=0.12->pytest->pyLDAvis) (0.5.1)

# %%
#!pip install spacy==2.1.9
#!pip install pymorphy2==0.8
#!pip uninstall msgpack-python

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mdere\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('dataset.csv', index_col=0)
data = df['Review Text'].tolist()

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['не', 'скачивается', 'стала', 'обновлять', 'зависло', 'приложение', 'что', 'случилось']]

# %%
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# C:\Users\mdere\Anaconda3\lib\site-packages\gensim\models\phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# ['не', 'скачивается', 'стала', 'обновлять', 'зависло', 'приложение', 'что', 'случилось']

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]
def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
data_words_nostops = remove_stopwords(data_words)
# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('ru2')
# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
print(data_lemmatized[:1])
# Out:
# [['скачиваться', 'стать', 'обновлять', 'зависнуть', 'приложение', 'случиться']]

# %%
id2word = corpora.Dictionary(data_lemmatized)
# Create Corpus
texts = data_lemmatized
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)]]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=120, 
                                           random_state=100,
                                           update_every=10,
                                           chunksize=10000,
                                           passes=10,
                                           per_word_topics=True)
# Out:
# C:\Users\mdere\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
= datapath('C:\\Users\\mdere\\source\\repos\\SberOnline\\Code\\model2\\model')

# %%
lda_model.save(temp_file)
# Out:
# C:\Users\mdere\Anaconda3\lib\site-packages\smart_open\smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
lda_model = gensim.models.ldamodel.LdaModel.load(temp_file)

# %%
lda_model.show_topics(num_topics=120)
# Out:
# [(0,
#   '0.046*"приложение" + 0.038*"самом" + 0.020*"бог" + 0.019*"банк" + 0.017*"удобный" + 0.016*"пин" + 0.014*"очень" + 0.014*"диван" + 0.012*"основнои" + 0.010*"крупный"'),
#  (1,
#   '0.040*"приложение" + 0.025*"ехать" + 0.016*"очень" + 0.016*"муж" + 0.015*"старую_версию" + 0.013*"удачный" + 0.012*"телефон" + 0.012*"сбербанк" + 0.011*"связать" + 0.010*"удобный"'),
#  (2,
#   '0.027*"период" + 0.022*"списание" + 0.020*"обновляться" + 0.017*"контроль" + 0.017*"магазин" + 0.016*"остаток" + 0.015*"видеть" + 0.015*"приложение" + 0.014*"карта" + 0.014*"трата"'),
#  (3,
#   '0.255*"спасибо" + 0.116*"очень" + 0.097*"удобный" + 0.092*"большой" + 0.065*"приложение" + 0.031*"лёгкий" + 0.028*"огромный" + 0.023*"удобство" + 0.015*"сбербанк" + 0.014*"работа"'),
#  (4,
#   '0.064*"получить" + 0.021*"уходить" + 0.021*"сутки" + 0.021*"списывать" + 0.020*"сбербанке" + 0.019*"деньга" + 0.019*"банк" + 0.015*"справка" + 0.015*"документ" + 0.013*"сделать"'),
#  (5,
#   '0.046*"приложение" + 0.045*"скачивать" + 0.044*"специалист" + 0.036*"внимание" + 0.027*"работать" + 0.022*"второи" + 0.018*"телефон" + 0.017*"благодарный" + 0.015*"благо" + 0.013*"спасибо"'),
#  (6,
#   '0.039*"приложение" + 0.027*"выити" + 0.019*"шикарный" + 0.017*"живой" + 0.017*"дизаин" + 0.016*"побольше" + 0.015*"наше_время" + 0.014*"очень" + 0.014*"шрифт" + 0.013*"удобный"'),
#  (7,
#   '0.060*"кнопка" + 0.022*"вариант" + 0.021*"далее" + 0.021*"ожидание" + 0.020*"привет" + 0.016*"частый" + 0.016*"кудато" + 0.015*"приложение" + 0.014*"нужный" + 0.013*"старая_версия"'),
#  (8,
#   '0.079*"первыи" + 0.068*"получиться" + 0.039*"часть" + 0.023*"плюс" + 0.020*"приложение" + 0.019*"спасибо" + 0.015*"проводиться" + 0.015*"валюта" + 0.015*"курс" + 0.013*"очень"'),
#  (9,
#   '0.143*"сервис" + 0.089*"удобныи" + 0.048*"хорошии" + 0.026*"очень" + 0.026*"мошенник" + 0.023*"банк" + 0.015*"защита" + 0.015*"служба" + 0.013*"работать" + 0.012*"приложение"'),
#  (10,
#   '0.128*"доступно" + 0.094*"воити" + 0.088*"понятный" + 0.061*"класс" + 0.061*"приложение" + 0.036*"очень" + 0.030*"удобный" + 0.027*"мочь" + 0.016*"ввода_пароля" + 0.013*"спасибо"'),
#  (11,
#   '0.035*"приложение" + 0.027*"старыи" + 0.026*"утро" + 0.021*"работать" + 0.017*"вечер" + 0.016*"тупит" + 0.016*"помнить" + 0.012*"забрать" + 0.012*"очень" + 0.010*"бабушка"'),
#  (12,
#   '0.029*"цель" + 0.026*"приложение" + 0.019*"рада" + 0.016*"оптимизация" + 0.016*"статистика" + 0.015*"очень" + 0.014*"сбербанк" + 0.014*"целеи" + 0.014*"толком" + 0.013*"активация"'),
#  (13,
#   '0.043*"поменять" + 0.027*"приложение" + 0.025*"автоплатежи" + 0.020*"другие_банки" + 0.019*"платежам" + 0.017*"быстрые_переводы" + 0.016*"очень" + 0.013*"нужный" + 0.012*"фио" + 0.012*"пишит"'),
#  (14,
#   '0.050*"очередь" + 0.026*"тема" + 0.025*"трудный" + 0.025*"стоять" + 0.024*"долг" + 0.018*"деться" + 0.016*"тяжёлый" + 0.016*"удобный" + 0.015*"приложение" + 0.014*"оплата"'),
#  (15,
#   '0.138*"рекомендую" + 0.103*"приложение" + 0.074*"удобный" + 0.059*"интуитивно" + 0.049*"очень" + 0.043*"понятный" + 0.029*"хороший" + 0.023*"других_банках" + 0.015*"стабильный" + 0.015*"ясный"'),
#  (16,
#   '0.086*"расход" + 0.036*"категория" + 0.029*"оплата" + 0.019*"анализ_финансов" + 0.018*"приложение" + 0.015*"месяц" + 0.015*"делаться" + 0.014*"штрих_коду" + 0.014*"удобный" + 0.013*"штрихкоду"'),
#  (17,
#   '0.027*"приложение" + 0.023*"карта" + 0.022*"саит" + 0.020*"ошибка" + 0.019*"выдавать" + 0.018*"мочь" + 0.017*"писать" + 0.016*"загрузить" + 0.016*"окно" + 0.016*"причина"'),
#  (18,
#   '0.023*"приложение" + 0.023*"продолжаите" + 0.021*"испортить" + 0.021*"дух" + 0.020*"труд" + 0.017*"устранить" + 0.016*"мелочь" + 0.016*"мелкий" + 0.015*"конец" + 0.013*"вывести"'),
#  (19,
#   '0.121*"приложение" + 0.088*"рука" + 0.062*"самое_лучшее" + 0.052*"балл" + 0.038*"удобный" + 0.029*"очень" + 0.019*"банк" + 0.014*"хороший" + 0.011*"комментарий" + 0.010*"использовании"'),
#  (20,
#   '0.085*"тормозить" + 0.069*"слишком" + 0.048*"приложение" + 0.043*"почемуто" + 0.021*"большои" + 0.013*"дополнительный" + 0.012*"устроистве" + 0.011*"контролировать" + 0.010*"предел" + 0.010*"удобный"'),
#  (21,
#   '0.085*"тупить" + 0.073*"становиться" + 0.062*"приложение" + 0.044*"каждым_обновлением" + 0.038*"худой" + 0.021*"хуже_хуже" + 0.017*"мина" + 0.015*"удобный" + 0.014*"очень" + 0.013*"обновление"'),
#  (22,
#   '0.049*"сбп" + 0.037*"вовремя" + 0.028*"приложение" + 0.024*"производить" + 0.023*"удобный" + 0.021*"сидя_дома" + 0.020*"пожелание" + 0.016*"очень" + 0.013*"подсказка" + 0.013*"далеко"'),
#  (23,
#   '0.053*"приложение" + 0.025*"сервер" + 0.020*"сравнивать" + 0.017*"киви" + 0.016*"жесть" + 0.015*"спасать" + 0.015*"два" + 0.015*"вместе" + 0.014*"центр" + 0.013*"товарищ"'),
#  (24,
#   '0.053*"бывать" + 0.052*"целом" + 0.050*"приложение" + 0.032*"моментально" + 0.026*"удобный" + 0.021*"очень" + 0.020*"создатель" + 0.019*"хороший" + 0.019*"обязательно" + 0.018*"задача"'),
#  (25,
#   '0.032*"надоесть" + 0.029*"всплывать" + 0.026*"терминал" + 0.017*"отключение" + 0.013*"приложение" + 0.009*"надоедать" + 0.009*"предложение" + 0.009*"обновление" + 0.009*"добро" + 0.009*"типо"'),
#  (26,
#   '0.061*"штраф" + 0.020*"оплата" + 0.018*"подходить" + 0.017*"приложение" + 0.016*"проведение" + 0.014*"присутствовать" + 0.013*"личном_кабинете" + 0.012*"загрузке" + 0.012*"терять" + 0.011*"сбербанк"'),
#  (27,
#   '0.118*"проблема" + 0.069*"оператор" + 0.040*"отвечать" + 0.034*"чат" + 0.031*"вопрос" + 0.025*"приложение" + 0.023*"чате" + 0.023*"возникать" + 0.021*"бот" + 0.020*"поддержка"'),
#  (28,
#   '0.078*"приложение" + 0.056*"требовать" + 0.044*"разрешение" + 0.030*"скачиваться" + 0.024*"доступ" + 0.019*"телефон" + 0.015*"ресурс" + 0.015*"антивирус" + 0.011*"работа" + 0.011*"мнение"'),
#  (29,
#   '0.109*"полностью" + 0.077*"вполне" + 0.042*"приложение" + 0.034*"удобный" + 0.030*"очень" + 0.023*"продумать" + 0.022*"преложение" + 0.018*"справляться" + 0.016*"ум" + 0.010*"интерфеиса"'),
#  (30,
#   '0.072*"место" + 0.036*"круто" + 0.031*"занимать" + 0.020*"оплате" + 0.020*"очень" + 0.019*"копеики" + 0.016*"оплата" + 0.015*"блин" + 0.014*"поддерживать" + 0.013*"телефон"'),
#  (31,
#   '0.064*"приложение" + 0.058*"андроид" + 0.055*"звезда" + 0.046*"ставить" + 0.022*"телефон" + 0.012*"достать" + 0.009*"невозможность" + 0.009*"версия" + 0.008*"интерфеисом" + 0.008*"очень"'),
#  (32,
#   '0.149*"номер" + 0.068*"телефон" + 0.026*"приложение" + 0.024*"карта" + 0.021*"банк" + 0.018*"доступ" + 0.016*"привязать" + 0.014*"контакт" + 0.011*"почему" + 0.010*"мочь"'),
#  (33,
#   '0.117*"баланс" + 0.071*"обновляется" + 0.069*"приложение" + 0.034*"виджет" + 0.012*"банкоматы" + 0.011*"телефон" + 0.011*"обновлять" + 0.009*"карта" + 0.009*"обновление" + 0.009*"виджете"'),
#  (34,
#   '0.180*"удобный" + 0.145*"очень" + 0.126*"быстро" + 0.086*"приложение" + 0.052*"понятный" + 0.049*"доступный" + 0.041*"спасибо" + 0.030*"рукои" + 0.026*"легко" + 0.024*"воскресенье"'),
#  (35,
#   '0.044*"разу" + 0.035*"приложение" + 0.035*"найти" + 0.034*"пока" + 0.030*"недостаток" + 0.028*"заметить" + 0.027*"платж" + 0.025*"минус" + 0.025*"проблема" + 0.022*"удобный"'),
#  (36,
#   '0.083*"приложение" + 0.082*"советовать" + 0.078*"очень" + 0.066*"выполнять" + 0.059*"удобный" + 0.054*"выручать" + 0.022*"хороший" + 0.020*"операция" + 0.019*"функция" + 0.016*"любои_момент"'),
#  (37,
#   '0.059*"банк" + 0.038*"приложение" + 0.036*"плакать" + 0.023*"высокий" + 0.022*"сравнению_другими" + 0.021*"современный" + 0.020*"выгодный" + 0.020*"отвратительныи" + 0.016*"согласие" + 0.015*"удобный"'),
#  (38,
#   '0.044*"снимать" + 0.040*"рублеи" + 0.038*"платить" + 0.035*"банк" + 0.029*"деньга" + 0.025*"месяц" + 0.024*"сбербанк" + 0.022*"услуга" + 0.020*"платный" + 0.017*"рубль"'),
#  (39,
#   '0.120*"вопрос" + 0.038*"ответить" + 0.023*"ответ" + 0.023*"копилка" + 0.019*"консультант" + 0.016*"разрабы" + 0.016*"работать" + 0.014*"темная_тема" + 0.014*"приложение" + 0.011*"улучшить"'),
#  (40,
#   '0.083*"деньга" + 0.042*"карта" + 0.034*"снять" + 0.022*"сбербанк" + 0.021*"банк" + 0.019*"заблокировать" + 0.017*"положить" + 0.017*"счёт" + 0.017*"прийти" + 0.017*"списать"'),
#  (41,
#   '0.173*"перевод" + 0.126*"комиссия" + 0.048*"банк" + 0.033*"переводы" + 0.032*"процент" + 0.023*"оплата" + 0.023*"сбербанк" + 0.020*"внутри" + 0.020*"лимит" + 0.019*"клиент"'),
#  (42,
#   '0.307*"время" + 0.054*"экономить" + 0.046*"очень" + 0.045*"приложение" + 0.041*"удобный" + 0.038*"звзд" + 0.016*"идт" + 0.013*"спосибо" + 0.013*"спасибо" + 0.013*"нерв"'),
#  (43,
#   '0.066*"пароль" + 0.044*"приложение" + 0.022*"обновление" + 0.019*"вход" + 0.018*"отпечаток" + 0.017*"палец" + 0.013*"писать" + 0.013*"мочь" + 0.012*"настроики" + 0.012*"выход"'),
#  (44,
#   '0.034*"напрягать" + 0.029*"очень" + 0.028*"приложение" + 0.025*"простои" + 0.024*"личный" + 0.022*"экономия_времени" + 0.022*"объяснить" + 0.021*"спасибо" + 0.019*"банк" + 0.017*"удобный"'),
#  (45,
#   '0.067*"приложение" + 0.025*"работать" + 0.024*"перестало_работать" + 0.015*"починить" + 0.014*"карта" + 0.013*"сбербанк" + 0.012*"телефон" + 0.009*"службу_поддержки" + 0.008*"гуд" + 0.007*"примерно"'),
#  (46,
#   '0.135*"уведомление" + 0.050*"смс" + 0.044*"сообщение" + 0.042*"приходить" + 0.039*"отображаться" + 0.031*"диалог" + 0.028*"приложение" + 0.025*"зачисление" + 0.012*"отключить" + 0.009*"операция"'),
#  (47,
#   '0.079*"замечательно" + 0.031*"поступать" + 0.026*"взять_кредит" + 0.024*"уметь" + 0.022*"бал" + 0.020*"работать" + 0.019*"приложение" + 0.015*"последним_обновлением" + 0.014*"перестала_работать" + 0.014*"спасибо"'),
#  (48,
#   '0.107*"ошибка" + 0.073*"писать" + 0.030*"приложение" + 0.028*"интернет" + 0.026*"мочь" + 0.022*"провести" + 0.017*"смысл" + 0.016*"обновление" + 0.014*"летать" + 0.012*"регистрация"'),
#  (49,
#   '0.047*"вклад" + 0.041*"поступление" + 0.021*"приложение" + 0.019*"деньга" + 0.018*"карта" + 0.017*"отслеживать" + 0.017*"средство" + 0.014*"очередеи" + 0.014*"счёт" + 0.014*"откуда"'),
#  (50,
#   '0.233*"стать" + 0.062*"приложение" + 0.047*"очень" + 0.043*"работать" + 0.043*"сильно" + 0.040*"обновление" + 0.032*"быстрее" + 0.027*"намного" + 0.019*"удобный" + 0.019*"медленно"'),
#  (51,
#   '0.241*"воскресенье" + 0.241*"устраивать" + 0.046*"приложение" + 0.039*"работать" + 0.035*"пока" + 0.013*"удобный" + 0.009*"спасибо" + 0.008*"понятно" + 0.008*"хороший" + 0.007*"банк"'),
#  (52,
#   '0.078*"приложение" + 0.051*"довольно" + 0.043*"хорошое" + 0.036*"краине" + 0.035*"замечание" + 0.020*"удобный" + 0.016*"сберу" + 0.012*"работать" + 0.012*"другими" + 0.012*"очень"'),
#  (53,
#   '0.093*"банк" + 0.073*"обслуживание" + 0.049*"брать" + 0.019*"клиент" + 0.017*"единственныи" + 0.016*"приложение" + 0.014*"скоро" + 0.012*"данным" + 0.011*"условие" + 0.011*"сбер"'),
#  (54,
#   '0.127*"смс" + 0.101*"приходить" + 0.051*"оповещение" + 0.021*"приложение" + 0.016*"ограничение" + 0.015*"карта" + 0.013*"цена" + 0.013*"подтверждение" + 0.011*"почему" + 0.011*"код"'),
#  (55,
#   '0.324*"пользоваться" + 0.086*"приложение" + 0.082*"очень" + 0.080*"удобный" + 0.055*"давно" + 0.042*"год" + 0.021*"этим_приложением" + 0.015*"постоянно" + 0.014*"пока" + 0.013*"хороший"'),
#  (56,
#   '0.173*"кредит" + 0.028*"приложение" + 0.020*"ипотека" + 0.018*"процент" + 0.017*"возможность" + 0.015*"платёж" + 0.013*"сумма" + 0.012*"давать" + 0.012*"заявка" + 0.011*"кредиту"'),
#  (57,
#   '0.030*"бесплатно" + 0.023*"приложение" + 0.022*"недоступный" + 0.021*"нормальныи" + 0.015*"банк" + 0.014*"менеджер" + 0.013*"прогружается" + 0.009*"pushуведомления" + 0.009*"открытка" + 0.009*"специально"'),
#  (58,
#   '0.066*"реклама" + 0.061*"банк" + 0.017*"отвратительный" + 0.016*"приложение" + 0.014*"относиться" + 0.014*"своих_клиентов" + 0.013*"плата" + 0.011*"мусор" + 0.010*"альфа" + 0.010*"создавать"'),
#  (59,
#   '0.096*"прекрасный" + 0.064*"приложение" + 0.058*"очень" + 0.039*"удобный" + 0.022*"мобильно" + 0.021*"перекинуть" + 0.018*"работать" + 0.017*"персонал" + 0.011*"здоровый" + 0.010*"перебоев"'),
#  (60,
#   '0.039*"реклама" + 0.028*"приложение" + 0.026*"продукт" + 0.025*"нужный" + 0.021*"мешать" + 0.014*"убрать" + 0.013*"предложение" + 0.013*"отключить" + 0.012*"скрыть" + 0.011*"ставлю"'),
#  (61,
#   '0.128*"удалить" + 0.059*"вирус" + 0.056*"антивирус" + 0.050*"приложение" + 0.018*"телефон" + 0.015*"установить" + 0.012*"нужный" + 0.011*"сбербанк" + 0.010*"почему" + 0.009*"удалять"'),
#  (62,
#   '0.094*"четко" + 0.082*"чтко" + 0.067*"здорово" + 0.060*"работать" + 0.059*"быстро" + 0.042*"приложение" + 0.039*"спасибо" + 0.039*"очень" + 0.027*"удобный" + 0.020*"понятный"'),
#  (63,
#   '0.108*"удобный" + 0.101*"выходить" + 0.094*"очень" + 0.090*"оплачивать" + 0.087*"дома" + 0.041*"приложение" + 0.033*"платёж" + 0.028*"оплатить" + 0.022*"совершать" + 0.020*"счёт"'),
#  (64,
#   '0.127*"долго" + 0.058*"очень" + 0.057*"приложение" + 0.049*"интернет" + 0.044*"грузиться" + 0.038*"загружаться" + 0.028*"открываться" + 0.027*"минута" + 0.024*"грузит" + 0.018*"ждать"'),
#  (65,
#   '0.070*"отличное" + 0.037*"рядом" + 0.036*"приложение" + 0.026*"удобный" + 0.024*"очень" + 0.020*"порои" + 0.016*"рубеж" + 0.014*"лежать" + 0.013*"перевод" + 0.012*"узбекистан"'),
#  (66,
#   '0.109*"программа" + 0.050*"память" + 0.046*"приложение" + 0.038*"обновлять" + 0.029*"устанавливаться" + 0.027*"телефон" + 0.024*"телефоне" + 0.023*"обновление" + 0.015*"проверка" + 0.015*"занимать"'),
#  (67,
#   '0.029*"приложение" + 0.022*"карта" + 0.019*"дебетовый" + 0.016*"удобный" + 0.015*"очень" + 0.015*"отслеживание" + 0.014*"нужный" + 0.010*"получение" + 0.009*"повториться" + 0.008*"банк"'),
#  (68,
#   '0.133*"шаблон" + 0.044*"наити" + 0.034*"пропасть" + 0.023*"мочь" + 0.020*"обновление" + 0.019*"приложение" + 0.018*"выдат_ошибку" + 0.014*"сохранить" + 0.014*"платежеи" + 0.012*"платёж"'),
#  (69,
#   '0.064*"отличныи" + 0.039*"различный" + 0.039*"очень" + 0.028*"удобный" + 0.026*"надежно" + 0.020*"приложение" + 0.019*"квартплата" + 0.018*"услуга" + 0.017*"увеличить" + 0.014*"исправлять"'),
#  (70,
#   '0.233*"работать" + 0.208*"отлично" + 0.068*"приложение" + 0.040*"воскресенье" + 0.035*"удобный" + 0.031*"сбой" + 0.029*"спасибо" + 0.025*"очень" + 0.022*"стабильно" + 0.020*"прекрасно"'),
#  (71,
#   '0.141*"самое" + 0.137*"приложение" + 0.093*"удобный" + 0.080*"главное" + 0.068*"банковский" + 0.035*"главный" + 0.027*"очень" + 0.021*"банк" + 0.021*"хороший" + 0.015*"понятный"'),
#  (72,
#   '0.092*"глючит" + 0.071*"неделя" + 0.052*"приложение" + 0.028*"сторона" + 0.016*"работать" + 0.011*"вернуться" + 0.010*"есть" + 0.010*"знать" + 0.009*"замена" + 0.009*"мочь"'),
#  (73,
#   '0.060*"приложение" + 0.044*"выкидывать" + 0.029*"почта" + 0.024*"блокировка" + 0.023*"андроиде" + 0.018*"браузер" + 0.015*"очень" + 0.013*"работать" + 0.013*"сбрасывать" + 0.012*"картинка"'),
#  (74,
#   '0.124*"поставить" + 0.027*"приветствие" + 0.015*"осуществляться" + 0.014*"перевод" + 0.014*"осуществить" + 0.013*"приложение" + 0.012*"оценка" + 0.012*"звезда" + 0.011*"ввели_комиссию" + 0.010*"работать"'),
#  (75,
#   '0.049*"банк" + 0.046*"приложение" + 0.021*"самого" + 0.020*"тариф" + 0.015*"выше" + 0.012*"антивирус" + 0.012*"настолько" + 0.011*"нужный" + 0.010*"другими_банками" + 0.010*"телефон"'),
#  (76,
#   '0.108*"приложение" + 0.077*"втб" + 0.043*"сравнение" + 0.033*"функциональный" + 0.028*"навязчивый" + 0.024*"очень" + 0.018*"удобный" + 0.014*"загрузиться" + 0.012*"открыться" + 0.012*"топ"'),
#  (77,
#   '0.055*"данныи_момент" + 0.053*"приложение" + 0.028*"редко" + 0.026*"удобный" + 0.025*"удобныи_интерфеис" + 0.024*"приятно" + 0.022*"очень" + 0.018*"даннои" + 0.018*"зависеть" + 0.017*"логичный"'),
#  (78,
#   '0.116*"классный" + 0.091*"приложение" + 0.049*"удобный" + 0.046*"очень" + 0.031*"счетами" + 0.028*"управление" + 0.026*"минимум" + 0.020*"заморочка" + 0.014*"оптимизировать" + 0.014*"сравнить"'),
#  (79,
#   '0.051*"удовольствие" + 0.040*"очень" + 0.035*"удобный" + 0.030*"улучшение" + 0.029*"качественный" + 0.028*"спасибо" + 0.028*"приложение" + 0.024*"мегафон" + 0.021*"бежать" + 0.016*"сбербанк"'),
#  (80,
#   '0.049*"принцип" + 0.040*"привыкнуть" + 0.026*"адрес" + 0.026*"тормоз" + 0.018*"приложение" + 0.017*"год" + 0.016*"работать" + 0.015*"электроэнергия" + 0.014*"достаточный" + 0.012*"наступающим_новым"'),
#  (81,
#   '0.321*"супер" + 0.065*"приложение" + 0.044*"удобный" + 0.043*"очень" + 0.020*"удобно" + 0.019*"быстро" + 0.018*"понятныи_интерфеис" + 0.018*"спасибо" + 0.016*"максимально" + 0.015*"работать"'),
#  (82,
#   '0.035*"автоплатеж" + 0.031*"телефон" + 0.025*"приложение" + 0.019*"запустить" + 0.014*"оплата" + 0.011*"доп" + 0.011*"обновляла" + 0.010*"магазине" + 0.010*"сброс" + 0.009*"мочь"'),
#  (83,
#   '0.044*"код" + 0.022*"бред" + 0.018*"безопасность" + 0.016*"нужный" + 0.016*"вводить" + 0.015*"приложение" + 0.014*"фото" + 0.013*"удаться" + 0.013*"сканировать" + 0.010*"позже"'),
#  (84,
#   '0.106*"приложение" + 0.065*"постоянно" + 0.056*"вылетать" + 0.038*"обновление" + 0.038*"зависать" + 0.027*"работать" + 0.021*"виснет" + 0.021*"последнего_обновления" + 0.018*"загрузка" + 0.016*"заходить"'),
#  (85,
#   '0.201*"разработчик" + 0.102*"спасибо" + 0.098*"приложение" + 0.092*"удобный" + 0.087*"очень" + 0.074*"молодцы" + 0.054*"использование" + 0.017*"хороший" + 0.015*"держать" + 0.010*"никуда_ходить"'),
#  (86,
#   '0.058*"приложение" + 0.045*"удобный" + 0.029*"интерфеис" + 0.026*"понятныи" + 0.025*"очень" + 0.025*"клик" + 0.021*"оплатои" + 0.015*"встречать" + 0.015*"улучшаться" + 0.015*"предельно"'),
#  (87,
#   '0.121*"история" + 0.100*"операция" + 0.024*"платежеи" + 0.020*"платёж" + 0.018*"приложение" + 0.012*"информация" + 0.012*"проводить" + 0.011*"возможность" + 0.011*"поиск" + 0.011*"отображаться"'),
#  (88,
#   '0.140*"мочь" + 0.106*"приложение" + 0.081*"заити" + 0.047*"установить" + 0.046*"скачать" + 0.024*"почему" + 0.023*"обновление" + 0.017*"телефон" + 0.015*"обновить" + 0.014*"писать"'),
#  (89,
#   '0.060*"приложение" + 0.029*"греф" + 0.027*"отстои" + 0.024*"авторизация" + 0.023*"работать" + 0.020*"перезагружать" + 0.018*"выбрасывать" + 0.013*"банк" + 0.013*"мтс" + 0.011*"какихто"'),
#  (90,
#   '0.069*"приложение" + 0.032*"существовать" + 0.012*"ток" + 0.011*"описание" + 0.009*"работать" + 0.008*"нужный" + 0.008*"сделать" + 0.008*"телефон" + 0.007*"молчу" + 0.007*"обновление"'),
#  (91,
#   '0.029*"приложение" + 0.027*"закрывать" + 0.023*"отображаются" + 0.022*"счёт" + 0.021*"каждым_разом" + 0.020*"страховка" + 0.017*"оплата" + 0.014*"карта" + 0.014*"всеи" + 0.013*"qr_код"'),
#  (92,
#   '0.067*"приходиться" + 0.064*"приложение" + 0.045*"снова" + 0.024*"заново" + 0.022*"каждыи" + 0.020*"обновление" + 0.016*"заходить" + 0.014*"появляться" + 0.012*"нужный" + 0.011*"устанавливать"'),
#  (93,
#   '0.062*"приложение" + 0.038*"лагает" + 0.029*"навязчиво" + 0.023*"неудобство" + 0.023*"долгий" + 0.022*"каждои" + 0.016*"перезагрузка" + 0.015*"чаще" + 0.014*"притензии" + 0.012*"очень"'),
#  (94,
#   '0.219*"сбербанк" + 0.209*"онлаин" + 0.069*"приложение" + 0.042*"очень" + 0.032*"жизнь" + 0.027*"спасибо" + 0.023*"хороший" + 0.020*"удобный" + 0.011*"представлять" + 0.010*"здоровье"'),
#  (95,
#   '0.073*"замечательный" + 0.072*"приложение" + 0.071*"выполнить" + 0.038*"операция" + 0.017*"очень" + 0.013*"удобный" + 0.012*"хороший" + 0.012*"сберпэи" + 0.010*"совершать_любые" + 0.006*"хранить"'),
#  (96,
#   '0.105*"лишний" + 0.086*"очень" + 0.083*"оперативно" + 0.061*"рад" + 0.038*"классно" + 0.038*"удобный" + 0.027*"приложение" + 0.024*"спасибо" + 0.020*"работать" + 0.019*"красиво"'),
#  (97,
#   '0.107*"очень" + 0.104*"особенно" + 0.086*"удобный" + 0.082*"понравиться" + 0.061*"приложение" + 0.060*"радовать" + 0.028*"следить" + 0.025*"быстрыи" + 0.023*"оплата" + 0.019*"счёт"'),
#  (98,
#   '0.103*"приложение" + 0.063*"других_банков" + 0.059*"нормальный" + 0.047*"обновить" + 0.043*"версия" + 0.013*"работать" + 0.012*"удаление" + 0.012*"огонь" + 0.011*"последнии" + 0.011*"банк"'),
#  (99,
#   '0.045*"корректно" + 0.044*"приложение" + 0.033*"работать" + 0.028*"сбои" + 0.028*"интересный" + 0.027*"подключение" + 0.026*"очень" + 0.018*"век" + 0.016*"небольшой" + 0.014*"странный"'),
#  (100,
#   '0.209*"деньга" + 0.075*"перевести" + 0.058*"переводить" + 0.036*"перевод" + 0.030*"карта" + 0.024*"счёт" + 0.023*"мочь" + 0.019*"отправить" + 0.016*"приложение" + 0.015*"счт"'),
#  (101,
#   '0.082*"банк" + 0.078*"удобный" + 0.076*"ходить" + 0.070*"очень" + 0.049*"банкомат" + 0.042*"приложение" + 0.034*"нужный" + 0.027*"никуда" + 0.027*"бегать" + 0.021*"отделение"'),
#  (102,
#   '0.051*"уровень" + 0.041*"отношение" + 0.030*"приложение" + 0.019*"реализовать" + 0.018*"спасибо" + 0.016*"оперативный" + 0.012*"форма" + 0.011*"банк" + 0.010*"хватать" + 0.010*"работа"'),
#  (103,
#   '0.320*"карта" + 0.023*"другого_банка" + 0.021*"пополнить" + 0.020*"возможность" + 0.018*"перевод" + 0.015*"приложение" + 0.015*"однои" + 0.013*"другую" + 0.012*"функция" + 0.011*"сбербанк"'),
#  (104,
#   '0.275*"довольный" + 0.135*"очень" + 0.063*"приложение" + 0.040*"удобный" + 0.030*"спасибо" + 0.020*"работать" + 0.019*"работои" + 0.016*"вроде" + 0.011*"сбербанк" + 0.011*"вещь"'),
#  (105,
#   '0.134*"сумма" + 0.071*"показывать" + 0.028*"карте" + 0.021*"карта" + 0.021*"приложение" + 0.019*"остаток" + 0.016*"средство" + 0.015*"баланс" + 0.014*"отображать" + 0.013*"счёт"'),
#  (106,
#   '0.074*"приложение" + 0.037*"развиваться" + 0.026*"очень" + 0.024*"удобный" + 0.023*"простое_использовании" + 0.011*"работать" + 0.010*"постоянно" + 0.010*"конкурент" + 0.010*"меняите" + 0.009*"блокироваться"'),
#  (107,
#   '0.278*"нравиться" + 0.127*"очень" + 0.091*"удобно" + 0.065*"удобный" + 0.061*"приложение" + 0.049*"быстро" + 0.038*"воскресенье" + 0.025*"работать" + 0.025*"спасибо" + 0.020*"дальше"'),
#  (108,
#   '0.071*"приложение" + 0.058*"ясно" + 0.043*"удобный" + 0.036*"понятный" + 0.034*"возможностеи" + 0.034*"очень" + 0.025*"мама" + 0.023*"множество" + 0.021*"приложениеочень" + 0.020*"хороший"'),
#  (109,
#   '0.118*"бонус" + 0.090*"спасибо" + 0.051*"любить" + 0.030*"комфортный" + 0.027*"приложение" + 0.026*"очень" + 0.025*"сбербанк" + 0.025*"удобный" + 0.020*"бюджет" + 0.016*"начисление"'),
#  (110,
#   '0.154*"вход" + 0.047*"приложение" + 0.039*"пожалуиста" + 0.022*"возможность" + 0.022*"отпечатку_пальца" + 0.022*"настроиках" + 0.021*"включить" + 0.020*"сделаите" + 0.018*"почему" + 0.017*"отпечатку"'),
#  (111,
#   '0.030*"какието" + 0.029*"вчера" + 0.026*"работник" + 0.020*"задержка" + 0.020*"создать" + 0.018*"восстановить" + 0.017*"кода" + 0.017*"оплата" + 0.011*"приложение" + 0.011*"сегодня"'),
#  (112,
#   '0.209*"банк" + 0.075*"мобильныи" + 0.058*"россия" + 0.056*"самыи" + 0.041*"сбербанк" + 0.041*"приложение" + 0.030*"лучшии" + 0.028*"самыи_лучшии" + 0.023*"позволять" + 0.018*"хороший"'),
#  (113,
#   '0.069*"пополнение" + 0.014*"добавить" + 0.014*"счёт" + 0.013*"возможность" + 0.012*"сохранение" + 0.012*"разблокировка" + 0.012*"телефон" + 0.011*"разблокировать" + 0.011*"оплата" + 0.011*"приложение"'),
#  (114,
#   '0.106*"мир" + 0.040*"карта" + 0.025*"сбербанконлаин" + 0.020*"приложение" + 0.016*"банк" + 0.015*"работать" + 0.014*"позор" + 0.012*"добрыи" + 0.010*"сбербанк" + 0.010*"добавляться"'),
#  (115,
#   '0.343*"отличный" + 0.244*"приложение" + 0.066*"удобный" + 0.035*"очень" + 0.024*"понятный" + 0.019*"воскресенье" + 0.017*"спасибо" + 0.011*"работать" + 0.006*"жить" + 0.005*"предложение"'),
#  (116,
#   '0.040*"один" + 0.039*"разобраться" + 0.032*"приложение" + 0.022*"скачивание" + 0.021*"впечатление" + 0.020*"спокоино" + 0.015*"сила" + 0.012*"мочь" + 0.011*"газ" + 0.010*"рынок"'),
#  (117,
#   '0.152*"нормально" + 0.062*"работать" + 0.041*"приложение" + 0.028*"первого_раза" + 0.026*"оценить" + 0.016*"высота" + 0.013*"включаться" + 0.012*"ожидать" + 0.012*"хуже" + 0.009*"аифон"'),
#  (118,
#   '0.209*"простой" + 0.042*"приложение" + 0.029*"желать" + 0.025*"удобный" + 0.015*"очень" + 0.012*"банк" + 0.009*"выбираю" + 0.009*"понятный" + 0.008*"спасибо" + 0.007*"хороший"'),
#  (119,
#   '0.083*"крутой" + 0.041*"приложение" + 0.031*"очень" + 0.027*"глаз" + 0.019*"цвет" + 0.016*"белый" + 0.013*"фон" + 0.013*"удобный" + 0.012*"тема" + 0.011*"некуда"')]

# %%
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nPerplexity: ', lda_model.log_perplexity(corpus))
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -9.97867563431096
#
# Coherence Score:  0.39028887828455816

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9e1628e71544> in <module>
#       1 pyLDAvis.enable_notebook()
# ----> 2 vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
#       3 vis
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     117     """
#     118     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 119     return vis_prepare(**opts)
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics)
#     396    term_frequency = np.sum(term_topic_freq, axis=0)
#     397
# --> 398    topic_info         = _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs)
#     399    token_table        = _token_table(topic_info, term_topic_freq, vocab, term_frequency)
#     400    topic_coordinates = _topic_coordinates(mds, topic_term_dists, topic_proportion)
#
# ~\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py in _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs)
#     253
#     254    top_terms = pd.concat(Parallel(n_jobs=n_jobs)(delayed(_find_relevance_chunks)(log_ttd, log_lift, R, ls) \
# --> 255                                                  for ls in _job_chunks(lambda_seq, n_jobs)))
#     256    topic_dfs = map(topic_top_term_df, enumerate(top_terms.T.iterrows(), 1))
#     257    return pd.concat([default_term_info] + list(topic_dfs))
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~\Anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
def get_with_threshold(inputs, threshold):
    result = []
    for index, elem in enumerate(inputs):
        if elem >= threshold:
            result.append(index + 1)
    return result

# %%
df = pd.read_csv('answer_dataset.csv', index_col=0)
df.head()
# Out:
#                                  Developer Reply Text  \
# 56  Рады, что вам понравилось приложение!\nПоясним...
# 57  У нас никаких сбоев не было зафиксировано. Поз...
# 59  В нашем приложении нет рекламы, есть лишь пред...
# 60  Исходя из статистики, большинство наших клиент...
# 66  Включить возможность скачивания приложений бол...
#
#                                           Review Text
# 56  Разработчики молодцы Приложение достойное Но в...
# 57  Почему я не могу сегодня целый день зайти в пр...
# 59  Забили рекламой хорошее приложение Отключить н...
# 60  В условиях пандемии ввести комиссию говорит о ...
# 66  Невозможно скачать приложение с новым обновлен...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45639 entries, 56 to 130102
# Data columns (total 2 columns):
# Developer Reply Text    45639 non-null object
# Review Text             45639 non-null object
# dtypes: object(2)
# memory usage: 1.0+ MB

# %%
def distance(a, b):
    n, m = len(a), len(b)
    if n > m:
        a, b = b, a
        n, m = m, n

    current_row = range(n + 1)
    for i in range(1, m + 1):
        previous_row, current_row = current_row, [i] + [0] * n
        for j in range(1, n + 1):
            add, delete, change = previous_row[j] + 1, current_row[j - 1] + 1, previous_row[j - 1]
            if a[j - 1] != b[i - 1]:
                change += 1
            current_row[j] = min(add, delete, change)

    return current_row[n]

# %%
import sys

def get_answer(text, df):
    result = ""
    dist = sys.maxsize
    for entity in df.values:
        new_dist = distance(text[:25], entity[1][:25])
        if new_dist <= dist:
            dist = new_dist
            result = entity[0]
    return result

# %%
get_answer("Как мне завершить платеж если нет интернета", df[:2000])
# Out:
# 'При зависании рекомендуем выгрузить приложение из памяти телефона, перезагрузить устройство и войти в приложение снова. Добавим, что медленная работа программы, как правило, связана с нестабильным интернетом, попробуйте войти, используя другое соединение.'
